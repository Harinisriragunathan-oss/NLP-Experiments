# %%
sentence ="Anna University placement cell"
words = sentence.split()
for word in words:
  if word in ["Anna", "University"]:
    print(word, "/ B-ORG")
else:
    print(word, "/ O")
# Out:
# Anna / B-ORG
# University / B-ORG
# cell / O
